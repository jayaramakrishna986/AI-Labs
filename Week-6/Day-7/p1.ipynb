# %%
from langchain_ollama import ChatOllama

# %%
llm1=ChatOllama(model='llama3.2')

# %%
llm1.invoke("My name is Jairam").content
# Out:
# 'Hi Jairam, how are you doing today? Is there something I can help you with or would you like to chat?'

# %%
llm1.invoke("What is my name").content
# Out:
# "I don't know your name. I'm a large language model, I don't have the ability to store or recall personal information about individual users, including names. Each time you interact with me, it's a new conversation and I start from a blank slate. Would you like to tell me your name?"

# %%
messages=['My name is XYZ']

# %%
output=llm1.invoke(messages).content
output
# Out:
# "It's nice to meet you, XYZ! Is there something I can help you with or would you like to chat?"

# %%
messages.append('what is my name')
messages
# Out:
# ['My name is XYZ', 'what is my name']

# %%
output=llm1.invoke(messages).content
output
# Out:
# 'Your name is XYZ.'
