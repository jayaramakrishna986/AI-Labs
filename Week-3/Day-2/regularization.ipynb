# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv("C:\Programs12\AI_Labs\AI-Labs\DataSets\Melbourne_housing_FULL.csv")

# %%
dataset.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
dataset.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
dataset.shape
# Out:
# (34857, 21)

# %%
cols_to_use = ['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount', 
               'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price']
dataset = dataset[cols_to_use]

# %%
dataset.shape
# Out:
# (34857, 15)

# %%
dataset.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
coulms_to_fill_with_0=["Propertycount","Distance","Bedroom2","Bathroom","Car"]
dataset[coulms_to_fill_with_0]=dataset[coulms_to_fill_with_0].fillna(0)

# %%
dataset.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        0
# Distance             0
# CouncilArea          3
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
dataset["Landsize"]=dataset["Landsize"].fillna(dataset.Landsize.mean())
dataset["BuildingArea"]=dataset["BuildingArea"].fillna(dataset.BuildingArea.mean())

# %%
dataset.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          3
# Propertycount       0
# Distance            0
# CouncilArea         3
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price            7610
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
# Dummy or Hot Encoding
dataset=pd.get_dummies(dataset,drop_first=True)
dataset.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  \
# 1      160.2564  1480000.0              False  ...
# 2       79.0000  1035000.0              False  ...
# 4      150.0000  1465000.0              False  ...
# 5      160.2564   850000.0              False  ...
# 6      142.0000  1600000.0              False  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                False                              False
# 2                                False                              False
# ...

# %%
X=dataset.drop("Price",axis=1)
y=dataset["Price"]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression().fit(X_train,y_train)

# %%
model.score(X_test,y_test)
# Out:
# 0.13853683161476094

# %%
model.score(X_train,y_train)
# Out:
# 0.6827792395792722

# %%
from sklearn import linear_model
lasso_reg=linear_model.Lasso(alpha=50,max_iter=100,tol=0.1)
lasso_reg.fit(X_train,y_train)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(X_test,y_test)
# Out:
# 0.6636111369404489

# %%
lasso_reg.score(X_train,y_train)
# Out:
# 0.6766985624766824

# %%
from sklearn.linear_model import Ridge
ridge_reg=Ridge(alpha=50,max_iter=100,tol=0.1)
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.score(X_test,y_test)
# Out:
# 0.6670848945194959
