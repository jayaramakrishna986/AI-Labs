# %%
import pandas as pd

# %%
# df=pd.read_csv("DataSets\Melbourne_housing_FULL.csv")

# %%
# df

# %%
# df.info()

# %%
# df.describe()

# %%
# import numpy as np
# a1=np.arange(0,9,1)

# a=a1.reshape(3,3)
# print(a)

# %%
# try :
#     num=int(input("Enter a Number:"))
#     res=10/num
#     print(res)
# except ValueError:
#     print('Please Enter a correct value')

# except ZeroDivisionError:
#     print("Number cant be divided by zero")
# finally:
#     print("DOne")

# %%
filename=open("p1.txt","a")
filename.write("I am good")
filename.close()

# %%
filename=open("p1.txt","a")
filename.write("How are you?")
print(filename)
filename.close()
# Out:
# <_io.TextIOWrapper name='p1.txt' mode='a' encoding='cp1252'>

# %%
with open("p1.txt","a") as file:
    file.write("Our best year ever\n")
    file.write("we show up better")

# %%
import numpy as np

arr = np.array([[1, 2, 3],
                [4, 5, 6]])

print(np.median(arr, axis=0))
# Out:
# [2.5 3.5 4.5]

# %%
import  os
if os.path.exists('P1.py'):
    print("Path exists")
else:
    print("Path doesnot exists")
# Out:
# Path exists

# %%
b1=np.linspace(1,5,5)
print(b1.var())
# Out:
# 2.0

# %%
v1 = np.array([[1, 3, 45],
               [2, 4, 5]])

v2 = np.array([[6, 8, 2],
               [8, 5, 4]])

v3=np.cross(v1,v2)
print(v3)
# Out:
# [[-354  268  -10]
#  [  -9   32  -22]]

# %%
A=np.array([[2,0],[0,4]])
evalue,evectors1=np.linalg.eig(A)
print(evalue)
print(evectors1)
# Out:
# [2. 4.]
# [[1. 0.]
#  [0. 1.]]

# %%
arr4=np.array([1, 2, 3])
arr5=np.array([7, 8, 9])
res=arr4*arr5
res1=np.dot(arr4,arr5)
# res2=np.matmul(arr4,arr5)
# print(res)
print(res1)
# Out:
# 50

# %%
from scipy import stats

arr6 = [12,65,5,45,41,21,15,121,21,211,2,1215,12,2,14,12,1,51,21,1,51,4,14,5,5,15]
print(stats.mode(arr6))
# Out:
# ModeResult(mode=np.int64(5), count=np.int64(3))
