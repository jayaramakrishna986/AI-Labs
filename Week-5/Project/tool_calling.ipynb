# %%
#tool create
from langchain.tools import tool
@tool
def get_conversion_factor(base_currency:str,target_currency:str)->float:
    """
    This function the currency conversion factor between  a given base currency and a  target currency"""

    url="https://v6.exchangerate-api.com/v6/73a871b0c17567141ffa1c12/latest/{base_currency}/{target_currency}"

    response=requests.get(url)
