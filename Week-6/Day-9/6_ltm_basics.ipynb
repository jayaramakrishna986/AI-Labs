# %%
from langgraph.store.memory import InMemoryStore

# %%
store=InMemoryStore()

# %%
namespace=("user",'u1')

# %% [markdown]
# Creating Memories

# %%
store.put(namespace,"1",{'data':"User likes pizza"})
store.put(namespace,"2",{'data':"user perfers dark mode"})

# %%
namespace2=("user",'u2')
store.put(namespace2,"1",{'data':"user like pasta"})
store.put(namespace2,"2",{'data':"user perfers grid like navigation"})

# %% [markdown]
# retreving memory

# %%
store.get(namespace2,"2")
# Out:
# Item(namespace=['user', 'u2'], key='2', value={'data': 'user perfers grid like navigation'}, created_at='2026-06-10T12:51:04.248479+00:00', updated_at='2026-06-10T12:51:04.248480+00:00')

# %% [markdown]
# Retrevinf all memories

# %%
items=store.search(namespace2)
for item in items:
    print(item.value)
# Out:
# {'data': 'user like pasta'}
# {'data': 'user perfers grid like navigation'}

# %% [markdown]
# Semantic search

# %%
from langchain_ollama import OllamaEmbeddings
embedding_model=OllamaEmbeddings(model='llama3')

# %%
store=InMemoryStore(index={'embed':embedding_model,'dims':1536})

# %%
namespace=('users','u1')

# %%
store.put(namespace,'1',{'data':"users perfers concise answers along explantion"})
store.put(namespace,'2',{'data':"User likes examples in python"})
store.put(namespace,'3',{'data':'users usually works at late night'})
store.put(namespace,'4',{'data':'user pefers dark mode in applications'})
store.put(namespace, "5", {"data": "User is learning machine learning"})
store.put(namespace, "6", {"data": "User dislikes overly theoretical explanations"})
store.put(namespace, "7", {"data": "User prefers step-by-step reasoning"})
store.put(namespace, "8", {"data": "User is based in India"})
store.put(namespace, "9", {"data": "User likes real-world analogies"})
store.put(namespace, "10", {"data": "User prefers bullet points over paragraphs"})

# %%
items=store.search(namespace,query="what is the user currently learning",limit=1)
for item in items:
    print(item.value)
# Out:
# {'data': 'User prefers bullet points over paragraphs'}

# %%
items=store.search(namespace,query="what is users perferences",limit=3)
for item in items:
    print(item.value)
# Out:
# {'data': 'User prefers bullet points over paragraphs'}
# {'data': 'User dislikes overly theoretical explanations'}
# {'data': 'User prefers step-by-step reasoning'}
