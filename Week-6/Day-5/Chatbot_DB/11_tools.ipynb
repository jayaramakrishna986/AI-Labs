# %%
# %pip install -U duckduckgo-search langchain-community
# %pip install -U duckduckgo-search
# Out:
# Requirement already satisfied: duckduckgo-search in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (8.1.1)
# Requirement already satisfied: langchain-community in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (0.4.2)
# Requirement already satisfied: click>=8.1.8 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from duckduckgo-search) (8.3.2)
# Requirement already satisfied: primp>=0.15.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from duckduckgo-search) (1.3.1)
# Requirement already satisfied: lxml>=5.3.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from duckduckgo-search) (6.1.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (3.14.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (1.4.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (0.8.7)
# Requirement already satisfied: numpy>=2.1.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (2.0.50)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.16)
# Requirement already satisfied: packaging>=23.2.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.13.0)
# Requirement already satisfied: certifi in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.7.0)
# Requirement already satisfied: greenlet>=1 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.1)
# Requirement already satisfied: colorama in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: duckduckgo-search in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (8.1.1)
# Requirement already satisfied: click>=8.1.8 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from duckduckgo-search) (8.3.2)
# Requirement already satisfied: primp>=0.15.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from duckduckgo-search) (1.3.1)
# Requirement already satisfied: lxml>=5.3.0 in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from duckduckgo-search) (6.1.1)
# Requirement already satisfied: colorama in c:\programs12\ai_labs\ai-labs\venv\lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_ollama import ChatOllama
from langgraph.graph.message import add_messages
from dotenv import load_dotenv

from langgraph.prebuilt import ToolNode, tools_condition
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import tool

import requests
import random
# Out:
# c:\Programs12\AI_Labs\AI-Labs\venv\Lib\site-packages\langchain_core\utils\pydantic.py:41: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1
# C:\Users\JayaramakrishnaMedis\AppData\Local\Temp\ipykernel_23768\3438668462.py:9: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun

# %%
llm = ChatOllama(model="llama3.2")

# %%
# Tools
search_tool = DuckDuckGoSearchRun(region="us-en")

@tool
def calculator(first_num: float, second_num: float, operation: str) -> dict:
    """
    Perform a basic arithmetic operation on two numbers.
    Supported operations: add, sub, mul, div
    """
    try:
        if operation == "add":
            result = first_num + second_num
        elif operation == "sub":
            result = first_num - second_num
        elif operation == "mul":
            result = first_num * second_num
        elif operation == "div":
            if second_num == 0:
                return {"error": "Division by zero is not allowed"}
            result = first_num / second_num
        else:
            return {"error": f"Unsupported operation '{operation}'"}
        
        return {"first_num": first_num, "second_num": second_num, "operation": operation, "result": result}
    except Exception as e:
        return {"error": str(e)}


@tool
def get_stock_price(symbol: str) -> dict:
    """
    Fetch latest stock price for a given symbol (e.g. 'AAPL', 'TSLA') 
    using Alpha Vantage with API key in the URL.
    """
    url = f"https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={symbol}&apikey=C9PE94QUEW9VWGFM"
    r = requests.get(url)
    return r.json()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Programs12\AI_Labs\AI-Labs\venv\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:49, in DuckDuckGoSearchAPIWrapper.validate_environment(cls, values)
#      48 try:
# ---> 49     from ddgs import DDGS  # noqa: F401
#      50 except ImportError:
#
# ModuleNotFoundError: No module named 'ddgs'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Tools
# ----> 2 search_tool = DuckDuckGoSearchRun(region="us-en")
#       3
#       4 @tool
#       5 def calculator(first_num: float, second_num: float, operation: str) -> dict:
#
# File c:\Programs12\AI_Labs\AI-Labs\venv\Lib\site-packages\langchain_core\tools\base.py:551, in BaseTool.__init__(self, **kwargs)
#     546     msg = (
#     547         "args_schema must be a subclass of pydantic BaseModel or "
#     548         f"a JSON schema dict. Got: {kwargs['args_schema']}."
#     549     )
#     550     raise TypeError(msg)
# --> 551 super().__init__(**kwargs)
#
# File c:\Programs12\AI_Labs\AI-Labs\venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 2 frame]
#
# File c:\Programs12\AI_Labs\AI-Labs\venv\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:51, in DuckDuckGoSearchAPIWrapper.validate_environment(cls, values)
#      49     from ddgs import DDGS  # noqa: F401
#      50 except ImportError:
# ---> 51     raise ImportError(
#      52         "Could not import ddgs python package. "
#      53         "Please install it with `pip install -U ddgs`."
#      54     )
#      55 return values
#
# ImportError: Could not import ddgs python package. Please install it with `pip install -U ddgs`.
