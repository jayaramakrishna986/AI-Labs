# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-proj-"

# %%
# !pip install langchain chromadb openai tiktoken pypdf langchain-ollama langchain-community chromadb
# Out:
# Requirement already satisfied: langchain in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (1.3.1)
# Requirement already satisfied: chromadb in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (1.5.9)
# Requirement already satisfied: openai in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (2.38.0)
# Requirement already satisfied: tiktoken in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (0.13.0)
# Requirement already satisfied: pypdf in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (6.12.1)
# Requirement already satisfied: langchain-ollama in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-community in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain) (1.2.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain) (2.13.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (4.1.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.0->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (4.13.0)
# Requirement already satisfied: certifi in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.12)
# Requirement already satisfied: h11>=0.16 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: build>=1.0.3 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.45.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (2.4.6)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (36.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from openai) (0.15.0)
# Requirement already satisfied: sniffio in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: regex in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from tiktoken) (2026.5.9)
# Requirement already satisfied: ollama<1.0.0,>=0.6.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-ollama) (0.6.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.7.0)
# Requirement already satisfied: greenlet>=1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: pyproject_hooks in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.63b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.16.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.0)
# Requirement already satisfied: click>=8.2.1 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programs12\ai_labs\ai-labs\fastapi\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# from langchain_ollama import OllamaEmbeddings
# from langchain.vectorstores import Chroma

from langchain_ollama import OllamaEmbeddings
from langchain_community.vectorstores import Chroma

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=OllamaEmbeddings(model="nomic-embed-text"),
    persist_directory='my_chroma_db',
    collection_name='sample'
)

# %%
# add documents
vector_store.add_documents(docs)
# Out:
# ['32c44fb0-3b96-46d2-bcb7-b948462f4371',
#  '1cfa28af-af8d-4f89-9eab-0048b94949c7',
#  'c01cab98-9363-4dfe-874d-2d80713d44fa',
#  '69081e04-2782-421c-8a64-7388e03d9eba',
#  '7fae486c-1a64-4806-8970-9eb12e884bcb']

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['e7f1e940-92ff-47b7-9c02-38584077851b',
#   '1adff1de-2f84-451b-adca-54b20f072a83',
#   '9b9f8072-ecf5-4bc5-92de-857fb2f60ee3',
#   'd5bd8a1f-4369-4926-8113-699065323081',
#   '51d277fb-7ad0-435f-9196-359d2b98cc27',
#   'e092e123-d59e-43be-829d-1fbab63017fe',
#   '739af11a-5ff9-4309-aeae-63bad0914d12',
#   '55eef7fb-222e-4d23-b4e2-b5f4dcb85171',
#   '6d7f9fb0-299b-4255-b235-f51b5551f1e5',
#   'f560ed03-7555-4b82-8dd0-8bac7a41debe',
#   'd70a23e4-8c96-411f-9ad3-54d1a06d9137',
#   'e329afb3-da6b-4c14-8954-d71f922fbc44',
#   '22b7f7d2-a2a0-4126-bbf4-af209fcd9fd5',
#   '46e66186-5e3a-4166-9a48-f127a6dbde31',
#   '2a35e7ea-c22f-4d88-a595-622d9073b20e',
#   '32c44fb0-3b96-46d2-bcb7-b948462f4371',
#   '1cfa28af-af8d-4f89-9eab-0048b94949c7',
#   'c01cab98-9363-4dfe-874d-2d80713d44fa',
#   '69081e04-2782-421c-8a64-7388e03d9eba',
#   '7fae486c-1a64-4806-8970-9eb12e884bcb'],
#  'embeddings': array([[-0.02584216,  0.06713498, -0.19005638, ..., -0.00406082,
#          -0.03328682, -0.00085129],
#         [-0.01343701,  0.05089365, -0.20069344, ..., -0.03863654,
#          -0.02799351, -0.02394386],
#         [ 0.00832589,  0.04186225, -0.1896449 , ..., -0.01787445,
#          -0.05385739, -0.02260349],
#         ...,
#         [ 0.00832589,  0.04186225, -0.1896449 , ..., -0.01787445,
#          -0.05385739, -0.02260349],
#         [ 0.00184629,  0.02171613, -0.16102582, ..., -0.03718664,
#          -0.02421379, -0.02395204],
#         [-0.02649398,  0.01970335, -0.18462098, ...,  0.00094659,
#          -0.04138429,  0.03270398]], shape=(20, 768)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a dhoni',
    k=2
)
# Out:
# [Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.')]

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [(Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.5161241292953491),
#  (Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.5161241292953491)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.8457431793212891),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.8457431793212891),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.8457431793212891),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.8457431793212891)]

# %%
# update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='09a39dc6-3ba6-4ea7-927e-fdda591da5e4', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['e7f1e940-92ff-47b7-9c02-38584077851b',
#   '1adff1de-2f84-451b-adca-54b20f072a83',
#   '9b9f8072-ecf5-4bc5-92de-857fb2f60ee3',
#   'd5bd8a1f-4369-4926-8113-699065323081',
#   '51d277fb-7ad0-435f-9196-359d2b98cc27',
#   'e092e123-d59e-43be-829d-1fbab63017fe',
#   '739af11a-5ff9-4309-aeae-63bad0914d12',
#   '55eef7fb-222e-4d23-b4e2-b5f4dcb85171',
#   '6d7f9fb0-299b-4255-b235-f51b5551f1e5',
#   'f560ed03-7555-4b82-8dd0-8bac7a41debe',
#   'd70a23e4-8c96-411f-9ad3-54d1a06d9137',
#   'e329afb3-da6b-4c14-8954-d71f922fbc44',
#   '22b7f7d2-a2a0-4126-bbf4-af209fcd9fd5',
#   '46e66186-5e3a-4166-9a48-f127a6dbde31',
#   '2a35e7ea-c22f-4d88-a595-622d9073b20e',
#   '32c44fb0-3b96-46d2-bcb7-b948462f4371',
#   '1cfa28af-af8d-4f89-9eab-0048b94949c7',
#   'c01cab98-9363-4dfe-874d-2d80713d44fa',
#   '69081e04-2782-421c-8a64-7388e03d9eba',
#   '7fae486c-1a64-4806-8970-9eb12e884bcb'],
#  'embeddings': array([[-0.02584216,  0.06713498, -0.19005638, ..., -0.00406082,
#          -0.03328682, -0.00085129],
#         [-0.01343701,  0.05089365, -0.20069344, ..., -0.03863654,
#          -0.02799351, -0.02394386],
#         [ 0.00832589,  0.04186225, -0.1896449 , ..., -0.01787445,
#          -0.05385739, -0.02260349],
#         ...,
#         [ 0.00832589,  0.04186225, -0.1896449 , ..., -0.01787445,
#          -0.05385739, -0.02260349],
#         [ 0.00184629,  0.02171613, -0.16102582, ..., -0.03718664,
#          -0.02421379, -0.02395204],
#         [-0.02649398,  0.01970335, -0.18462098, ...,  0.00094659,
#          -0.04138429,  0.03270398]], shape=(20, 768)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# delete document
vector_store.delete(ids=['09a39dc6-3ba6-4ea7-927e-fdda591da5e4'])

# %%
print(docs)
# Out:
# [Document(metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.'), Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."), Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'), Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'), Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['e7f1e940-92ff-47b7-9c02-38584077851b',
#   '1adff1de-2f84-451b-adca-54b20f072a83',
#   '9b9f8072-ecf5-4bc5-92de-857fb2f60ee3',
#   'd5bd8a1f-4369-4926-8113-699065323081',
#   '51d277fb-7ad0-435f-9196-359d2b98cc27',
#   'e092e123-d59e-43be-829d-1fbab63017fe',
#   '739af11a-5ff9-4309-aeae-63bad0914d12',
#   '55eef7fb-222e-4d23-b4e2-b5f4dcb85171',
#   '6d7f9fb0-299b-4255-b235-f51b5551f1e5',
#   'f560ed03-7555-4b82-8dd0-8bac7a41debe',
#   'd70a23e4-8c96-411f-9ad3-54d1a06d9137',
#   'e329afb3-da6b-4c14-8954-d71f922fbc44',
#   '22b7f7d2-a2a0-4126-bbf4-af209fcd9fd5',
#   '46e66186-5e3a-4166-9a48-f127a6dbde31',
#   '2a35e7ea-c22f-4d88-a595-622d9073b20e',
#   '1cfa28af-af8d-4f89-9eab-0048b94949c7',
#   'c01cab98-9363-4dfe-874d-2d80713d44fa',
#   '69081e04-2782-421c-8a64-7388e03d9eba',
#   '7fae486c-1a64-4806-8970-9eb12e884bcb'],
#  'embeddings': array([[-0.02584216,  0.06713498, -0.19005638, ..., -0.00406082,
#          -0.03328682, -0.00085129],
#         [-0.01343701,  0.05089365, -0.20069344, ..., -0.03863654,
#          -0.02799351, -0.02394386],
#         [ 0.00832589,  0.04186225, -0.1896449 , ..., -0.01787445,
#          -0.05385739, -0.02260349],
#         ...,
#         [ 0.00832589,  0.04186225, -0.1896449 , ..., -0.01787445,
#          -0.05385739, -0.02260349],
#         [ 0.00184629,  0.02171613, -0.16102582, ..., -0.03718664,
#          -0.02421379, -0.02395204],
#         [-0.02649398,  0.01970335, -0.18462098, ...,  0.00094659,
#          -0.04138429,  0.03270398]], shape=(19, 768)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
print(docs)
# Out:
# [Document(metadata={'team': 'Royal Challengers Bangalore'}, page_content='Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.'), Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."), Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'), Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'), Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['e7f1e940-92ff-47b7-9c02-38584077851b',
#   '1adff1de-2f84-451b-adca-54b20f072a83',
#   '9b9f8072-ecf5-4bc5-92de-857fb2f60ee3',
#   'd5bd8a1f-4369-4926-8113-699065323081',
#   '51d277fb-7ad0-435f-9196-359d2b98cc27',
#   'e092e123-d59e-43be-829d-1fbab63017fe',
#   '739af11a-5ff9-4309-aeae-63bad0914d12',
#   '55eef7fb-222e-4d23-b4e2-b5f4dcb85171',
#   '6d7f9fb0-299b-4255-b235-f51b5551f1e5',
#   'f560ed03-7555-4b82-8dd0-8bac7a41debe',
#   'd70a23e4-8c96-411f-9ad3-54d1a06d9137',
#   'e329afb3-da6b-4c14-8954-d71f922fbc44',
#   '22b7f7d2-a2a0-4126-bbf4-af209fcd9fd5',
#   '46e66186-5e3a-4166-9a48-f127a6dbde31',
#   '2a35e7ea-c22f-4d88-a595-622d9073b20e',
#   '32c44fb0-3b96-46d2-bcb7-b948462f4371',
#   '1cfa28af-af8d-4f89-9eab-0048b94949c7',
#   'c01cab98-9363-4dfe-874d-2d80713d44fa',
#   '69081e04-2782-421c-8a64-7388e03d9eba',
#   '7fae486c-1a64-4806-8970-9eb12e884bcb'],
#  'embeddings': array([[-0.02584216,  0.06713498, -0.19005638, ..., -0.00406082,
#          -0.03328682, -0.00085129],
#         [-0.01343701,  0.05089365, -0.20069344, ..., -0.03863654,
#          -0.02799351, -0.02394386],
#         [ 0.00832589,  0.04186225, -0.1896449 , ..., -0.01787445,
#          -0.05385739, -0.02260349],
#         ...,
#         [ 0.00832589,  0.04186225, -0.1896449 , ..., -0.01787445,
#          -0.05385739, -0.02260349],
#         [ 0.00184629,  0.02171613, -0.16102582, ..., -0.03718664,
#          -0.02421379, -0.02395204],
#         [-0.02649398,  0.01970335, -0.18462098, ...,  0.00094659,
#          -0.04138429,  0.03270398]], shape=(20, 768)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.',
#   'Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}
