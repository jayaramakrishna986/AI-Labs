# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\JayaramakrishnaMedis\OneDrive - Aditi Consulting\Desktop\creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  1.175161e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
sns.countplot(x='Class',data=df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df["Amount"].value_counts()
# Out:
# Amount
# 1.00      13688
# 1.98       6044
# 0.89       4872
# 9.99       4747
# 15.00      3280
#           ...
# 787.95        1
# 405.09        1
# 381.05        1
# 337.54        1
# 95.63         1
# Name: count, Length: 32767, dtype: int64

# %%
sns.histplot(df["Amount"],bins=200)
# Out:
# <Axes: xlabel='Amount', ylabel='Count'>

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
df["Amount_scaled"]=scaler.fit_transform(df[["Amount"]])
# df.drop('Amount',axis=1,inplace=True)

# %%
fraud=df[df['Class']==1]
normal=df[df['Class']==0]

fraud.describe()
normal.describe()
# Out:
#                 Time             V1  ...     Class  Amount_scaled
# count  284315.000000  284315.000000  ...  284315.0  284315.000000
# mean    94838.202258       0.008258  ...       0.0      -0.000234
# std     47484.015786       1.929814  ...       0.0       0.999942
# min         0.000000     -56.407510  ...       0.0      -0.353229
# 25%     54230.000000      -0.917544  ...       0.0      -0.330640
# 50%     84711.000000       0.020023  ...       0.0      -0.265271
# 75%    139333.000000       1.316218  ...       0.0      -0.045177
# max    172792.000000       2.454930  ...       0.0     102.362243
#
# [8 rows x 32 columns]

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V28  Amount  Class  Amount_scaled
# 0   0.0 -1.359807 -0.072781  2.536347  ... -0.021053  149.62      0       0.244964
# 1   0.0  1.191857  0.266151  0.166480  ...  0.014724    2.69      0      -0.342475
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.059752  378.66      0       1.160686
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.061458  123.50      0       0.140534
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.215153   69.99      0      -0.073403
#
# [5 rows x 32 columns]

# %%
print(df["Class"].value_counts())
sns.countplot(data=df,x="Class")
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
# <Axes: xlabel='Class', ylabel='count'>

# %%
sns.histplot(fraud["Amount_scaled"],color='red',label='Fraud',kde=True)
sns.histplot(fraud["Amount_scaled"],color='blue',label="Normal",kde=True)
plt.legend()
plt.show()

# %%
print(df[df["Class"]==1].value_counts().sum())
# Out:
# 492

# %%
sns.boxplot(x=df["Amount_scaled"])
# Out:
# <Axes: xlabel='Amount_scaled'>

# %%
from sklearn.utils import resample
normal_sample=resample(normal,replace=False,n_samples=len(fraud),random_state=42)
df_balanced=pd.concat([normal_sample,fraud])

# %%
df.shape
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 32 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Time           284807 non-null  float64
#  1   V1             284807 non-null  float64
#  2   V2             284807 non-null  float64
#  3   V3             284807 non-null  float64
#  4   V4             284807 non-null  float64
#  5   V5             284807 non-null  float64
#  6   V6             284807 non-null  float64
#  7   V7             284807 non-null  float64
#  8   V8             284807 non-null  float64
#  9   V9             284807 non-null  float64
#  10  V10            284807 non-null  float64
#  11  V11            284807 non-null  float64
#  12  V12            284807 non-null  float64
#  13  V13            284807 non-null  float64
#  14  V14            284807 non-null  float64
#  15  V15            284807 non-null  float64
#  16  V16            284807 non-null  float64
# ...

# %%
print(df.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class', 'Amount_scaled'],
#       dtype='str')

# %%
df.iloc[1]
# Out:
# Time             0.000000
# V1               1.191857
# V2               0.266151
# V3               0.166480
# V4               0.448154
# V5               0.060018
# V6              -0.082361
# V7              -0.078803
# V8               0.085102
# V9              -0.255425
# V10             -0.166974
# V11              1.612727
# V12              1.065235
# V13              0.489095
# V14             -0.143772
# V15              0.635558
# V16              0.463917
# V17             -0.114805
# V18             -0.183361
# V19             -0.145783
# V20             -0.069083
# V21             -0.225775
# V22             -0.638672
# V23              0.101288
# V24             -0.339846
# V25              0.167170
# V26              0.125895
# V27             -0.008983
# V28              0.014724
# Amount           2.690000
# Class            0.000000
# Amount_scaled   -0.342475
# Name: 1, dtype: float64

# %%
df.iloc[:,:-1]
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time             0
# V1               0
# V2               0
# V3               0
# V4               0
# V5               0
# V6               0
# V7               0
# V8               0
# V9               0
# V10              0
# V11              0
# V12              0
# V13              0
# V14              0
# V15              0
# V16              0
# V17              0
# V18              0
# V19              0
# V20              0
# V21              0
# V22              0
# V23              0
# V24              0
# V25              0
# V26              0
# V27              0
# V28              0
# Amount           0
# Class            0
# Amount_scaled    0
# dtype: int64

# %%
fraud_count=df[df["Class"]==1].value_counts().sum()
normal_count=df[df["Class"]==0].value_counts().sum()

total=df["Class"].value_counts().sum()
print(total)

percentage=(fraud/total)
print(percentage*100)
# Out:
# 284807
#              Time        V1        V2  ...    Amount     Class  Amount_scaled
# 541      0.142553 -0.000812  0.000685  ...  0.000000  0.000351      -0.000124
# 623      0.165726 -0.001069 -0.001109  ...  0.185740  0.000351       0.000619
# 4920     1.566675 -0.000809  0.000618  ...  0.084243  0.000351       0.000213
# 6108     2.452889 -0.001544  0.000477  ...  0.020716  0.000351      -0.000041
# 6329     2.640033  0.000433  0.001060  ...  0.000351  0.000351      -0.000123
# ...           ...       ...       ...  ...       ...       ...            ...
# 279863  59.388288 -0.000677  0.000395  ...  0.136935  0.000351       0.000423
# 280143  59.460266  0.000484  0.000453  ...  0.000267  0.000351      -0.000123
# 280149  59.461671 -0.000237  0.000395  ...  0.027348  0.000351      -0.000015
# 281144  59.677606 -0.001093  0.000206  ...  0.086023  0.000351       0.000220
# 281674  59.811732  0.000699  0.000056  ...  0.014933  0.000351      -0.000064
#
# [492 rows x 32 columns]

# %%
sns.countplot(data=df,x="Class")
plt.title("Class Distrubution")
# sns.histplot(x='Amount',axis=1)
plt.show()

# %%
sns.histplot(df["Amount"],bins=100)
plt.title("Transction Amount Distrubution")
plt.show()

# %%
#Level-2

df.groupby("Class").mean()
# Out:
#                Time        V1        V2  ...       V28      Amount  Amount_scaled
# Class                                    ...
# 0      94838.202258  0.008258 -0.006271  ... -0.000131   88.291022      -0.000234
# 1      80746.806911 -4.771948  3.623778  ...  0.075667  122.211321       0.135382
#
# [2 rows x 31 columns]

# %%
frauded1=df[df["Class"]==1]
Normal11=df[df["Class"]==0]

sns.histplot(frauded1["Amount"],color='red',kde=True)
# sns.histplot(Normal11["Amount"],color='blue',kde=True)
plt.legend()
# Out:
# C:\Users\JayaramakrishnaMedis\AppData\Local\Temp\ipykernel_32776\2573156003.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap='coolwarm')
# Out:
# <Axes: >

# %%
# from sklearn.model_selection import train_test_split

# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# Logistic regression
# from sklearn.linear_model import LogisticRegression
# model=LogisticRegression()
# model.fit(X_train,y_train)
# model.predict(X_test)

# %%
# from sklearn.metrics import classification_report

# print(classification_report(y_test,y_pred))

# %%
# Find top 10 transactions with highest Amount
top_10=df.nlargest(10,"Amount")
print(df[["Amount","Class"]])
# Out:
#         Amount  Class
# 0       149.62      0
# 1         2.69      0
# 2       378.66      0
# 3       123.50      0
# 4        69.99      0
# ...        ...    ...
# 284802    0.77      0
# 284803   24.79      0
# 284804   67.88      0
# 284805   10.00      0
# 284806  217.00      0
#
# [284807 rows x 2 columns]

# %%
sns.histplot(df[df["Class"]==1]["Time"],bins=50)
# Out:
# <Axes: xlabel='Time', ylabel='Count'>

# %%
df["Amount"].skew()
# Out:
# np.float64(16.977724453761006)

# %%
df["Amount_log"]=np.log1p(df["Amount"])

# %%
sns.boxplot(data=df, x='Class', y='Amount')
plt.ylim(0, 500) # Zoom in because outliers hide the boxes
# Out:
# (0.0, 500.0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

models={
    "Logistic":LogisticRegression(max_iter=1000),
    "Decision tree":DecisionTreeClassifier(),
    "Random Forest":RandomForestClassifier()
}

# for name,model in models:
    # model.fit(X_train,y_train)
    # y_pred=model.predict(X_test)
    # print(classification_report(y_test,y_pred))

# %%
from sklearn.model_selection import cross_val_score

scores=cross_val_score(RandomForestClassifier(),X_res,y_res,cv=5,scoring="f1")
print(scores)
